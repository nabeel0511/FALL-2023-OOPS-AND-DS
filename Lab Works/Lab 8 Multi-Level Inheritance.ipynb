# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 20px 15px;
#         border-radius: 20px;
#         background: linear-gradient(135deg, #f9f9f9, #ffffff);
#         max-width: 900px; /* Increased width */
#         box-shadow: 0 8px 20px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 30px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 2px;
#             margin-bottom: 15px;
#         "
#     >
#         University of Engineering and Technology Peshawar
#     </h1>
#     <h2
#         style="
#             font-family: 'Georgia', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 5px;
#             font-style: italic;
#         "
#     >
#         Jalozai Campus
#     </h2>
# </div>

# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border-radius: 20px;
#         background: linear-gradient(135deg, #f3f4f6, #ffffff);
#         max-width: 800px;
#         box-shadow: 0 10px 25px rgba(0, 0, 0, 0.15);
#         text-align: center;
#         border: 1px solid #e0e0e0;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 32px;
#             color: #2c3e50;
#             text-transform: capitalize;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#             margin-bottom: 20px;
#         "
#     >
#         Lab Title: EE-271 “OOP & Data Structures Lab”
#     </h1>
# </div>

# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border-radius: 20px;
#         background: linear-gradient(135deg, #f3f4f6, #ffffff);
#         max-width: 800px;
#         box-shadow: 0 10px 25px rgba(0, 0, 0, 0.15);
#         text-align: center;
#         border: 1px solid #e0e0e0;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 25px;
#             color: #2c3e50;
#             text-transform: capitalize;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#             margin-bottom: 20px;
#         "
#     >
#         Lab 8: Inheritance
#     </h1>
# </div>

# %% [markdown]
# ## Prepared By: Nabeel Ahmad

# %% [markdown]
# ------------------------------------

# %% [markdown]
# <span style="color:rgb(167, 63, 63);
# font-size: 44px;
# transition: color 0.3s;">&#x21DD; </span>
# <span style="color:rgb(47, 204, 92);
#     font-family: Arial Black;
# font-size: 35px; font-weight: bold;
# text-shadow: 0px 4px 2px rgb(0, 0, 0);">
#     Lab Work Tasks :</span>

# %% [markdown]
# ## Problem 1:

# %% [markdown]
# <center>
#   <h3 style="color: #34495e; font-family: Arial, sans-serif; background-color: pink; padding: 8px; border-radius: 5px;">Rectangle → Square → Cube</h3>
# </center>
#
# <h3 style="color: #34495e; font-family: Arial, sans-serif;">Objective</h3>
# <p style="color: #2c3e50; font-family: Arial, sans-serif; line-height: 1.6;">
#   Define a class hierarchy that models a Rectangle, a Square (inheriting from Rectangle), and a Cube (inheriting from Square). The Cube class extends the functionality of the <code>area()</code> method to calculate surface area and volume.
# </p>
#
# <h3 style="color: #34495e; font-family: Arial, sans-serif;">Class Structure</h3>
# <ol style="color: #2c3e50; font-family: Arial, sans-serif; line-height: 1.8;">
#   <li>
#     <strong style="color: #2980b9; background-color: #eafaf1; padding: 5px; border-radius: 5px;">Rectangle Class:</strong>
#     <ul>
#       <li>This class has <code>length</code> and <code>width</code> as attributes.</li>
#       <li>It includes a method to calculate the area of the rectangle: <code>area()</code>.</li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #e67e22; background-color: #fceae5; padding: 5px; border-radius: 5px;">Square Class:</strong>
#     <ul>
#       <li>This class inherits from the <code>Rectangle</code> class.</li>
#       <li>Since a square has equal length and width, the constructor ensures both dimensions are equal.</li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #27ae60; background-color: #eafaf1; padding: 5px; border-radius: 5px;">Cube Class:</strong>
#     <ul>
#       <li>This class inherits from the <code>Square</code> class.</li>
#       <li>The <code>Cube</code> class extends functionality to calculate surface area and volume.</li>
#       <li>The <code>Cube</code> class uses the inherited <code>area()</code> method to determine its surface area.</li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #8e44ad; background-color: #f5e6fc; padding: 5px; border-radius: 5px;">Creating Instances:</strong>
#     <ul>
#       <li>Two instances of the <code>Cube</code> class are created.</li>
#       <li>Both instances call the instance methods to compute surface area and volume.</li>
#     </ul>
#   </li>
# </ol>

# %%
class Rectangle:
    """Represents a rectangle with length and width."""
    
    def __init__(self, length: float, width: float):
        """Initialize a rectangle with length and width."""
        self.length = length
        self.width = width

    def area(self) -> float:
        """Calculate and return the area of the rectangle."""
        return self.length * self.width

    def __str__(self):
        return f"Rectangle(length={self.length}, width={self.width})"


class Square(Rectangle):
    """Represents a square, which is a special type of rectangle with equal sides."""
    
    def __init__(self, side: float):
        """Initialize a square with equal length and width."""
        super().__init__(side, side)

    def __str__(self):
        return f"Square(side={self.length})"


class Cube(Square):
    """Represents a cube, which extends the square by adding volume and surface area calculations."""
    
    def __init__(self, side: float):
        """Initialize a cube with equal side lengths."""
        super().__init__(side)

    def surface_area(self) -> float:
        """Calculate and return the surface area of the cube."""
        return 6 * super().area()  # 6 sides of a square

    def volume(self) -> float:
        """Calculate and return the volume of the cube."""
        return self.length ** 3  # length is the same as width and height

    def __str__(self):
        return f"Cube(side={self.length})"

# %%
# Create two instances of the Cube class
cube1 = Cube(3)
cube2 = Cube(5)

# %%
# Call instance methods
print(f"{cube1} → Surface Area: {cube1.surface_area()}, Volume: {cube1.volume()}")
print(f"{cube2} → Surface Area: {cube2.surface_area()}, Volume: {cube2.volume()}")
# Out:
# Cube(side=3) → Surface Area: 54, Volume: 27
# Cube(side=5) → Surface Area: 150, Volume: 125

# %% [markdown]
#  ## Problem 2:

# %% [markdown]
# <center>
#   <h3 style="color: #34495e; font-family: Arial, sans-serif; background-color: pink; padding: 8px; border-radius: 5px;">Productivity System</h3>
# </center>
#
# <h3 style="color: #34495e; font-family: Arial, sans-serif;">Objective</h3>
# <p style="color: #2c3e50; font-family: Arial, sans-serif; line-height: 1.6;">
#   Define a class hierarchy for tracking employee productivity based on different roles. Each role should implement a <code>work()</code> method to define its functionality in the system.
# </p>
#
# <h3 style="color: #34495e; font-family: Arial, sans-serif;">Class Structure</h3>
# <ol style="color: #2c3e50; font-family: Arial, sans-serif; line-height: 1.8;">
#   <li>
#     <strong style="color: #2980b9; background-color: #eafaf1; padding: 5px; border-radius: 5px;">Manager Class:</strong>
#     <ul>
#       <li>The <code>Manager</code> class inherits from <code>SalaryEmployee</code>.</li>
#       <li>Managers are responsible for overseeing employees and making decisions.</li>
#       <li>They have a <code>work(hours)</code> method that defines their role as managing employees and giving instructions.</li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #e67e22; background-color: #fceae5; padding: 5px; border-radius: 5px;">Secretary Class:</strong>
#     <ul>
#       <li>The <code>Secretary</code> class inherits from <code>SalaryEmployee</code>.</li>
#       <li>Secretaries handle paperwork, billing, and administrative tasks.</li>
#       <li>They implement a <code>work(hours)</code> method that represents their role in supporting managers.</li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #27ae60; background-color: #eafaf1; padding: 5px; border-radius: 5px;">SalesPerson Class:</strong>
#     <ul>
#       <li>The <code>SalesPerson</code> class inherits from <code>SalaryEmployee</code>.</li>
#       <li>Sales employees sell products and receive commissions in addition to a base salary.</li>
#       <li>They implement a <code>work(hours)</code> method that represents their role in making sales calls and generating revenue.</li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #8e44ad; background-color: #f5e6fc; padding: 5px; border-radius: 5px;">FactoryWorker Class:</strong>
#     <ul>
#       <li>The <code>FactoryWorker</code> class inherits from <code>HourlyEmployee</code>.</li>
#       <li>Factory workers manufacture products and are paid based on their working hours.</li>
#       <li>They implement a <code>work(hours)</code> method that represents their role in assembling and producing goods.</li>
#     </ul>
#   </li>
# </ol>

# %%
# Base Employee Class
class Employee:
    def __init__(self, emp_id, name):
        self.emp_id = emp_id
        self.name = name
    
    def calculate_payroll(self):
        """This method should be implemented in the subclass."""
        raise NotImplementedError("This method should be overridden in the subclass.")

    def work(self, hours):
        """This method should be implemented in the subclass to track work done."""
        raise NotImplementedError("This method should be overridden in the subclass.")

# SalaryEmployee Class (inherits from Employee)
class SalaryEmployee(Employee):
    def __init__(self, emp_id, name, weekly_salary):
        super().__init__(emp_id, name)
        self.weekly_salary = weekly_salary
    
    def calculate_payroll(self):
        """Returns the weekly salary for salaried employees."""
        return self.weekly_salary
    
    def work(self, hours):
        """Track work for salaried employees. (Work could be symbolic for managers or secretaries)."""
        print(f"{self.name} worked for {hours} hours (Salary-based).")

# Manager Class (inherits from SalaryEmployee)
class Manager(SalaryEmployee):
    def __init__(self, emp_id, name, weekly_salary):
        super().__init__(emp_id, name, weekly_salary)
    
    def work(self, hours):
        """Managers typically work and delegate tasks."""
        print(f"Manager {self.name} worked for {hours} hours, delegating tasks and overseeing operations.")

# Secretary Class (inherits from SalaryEmployee)
class Secretary(SalaryEmployee):
    def __init__(self, emp_id, name, weekly_salary):
        super().__init__(emp_id, name, weekly_salary)
    
    def work(self, hours):
        """Secretaries do the paperwork and ensure everything gets done."""
        print(f"Secretary {self.name} worked for {hours} hours, handling paperwork and administration.")

# SalesPerson Class (inherits from SalaryEmployee)
class SalesPerson(SalaryEmployee):
    def __init__(self, emp_id, name, weekly_salary, commission_rate):
        super().__init__(emp_id, name, weekly_salary)
        self.commission_rate = commission_rate  # Commission rate as a percentage
        self.sales_made = 0  # Track the sales made by the employee

    def work(self, hours, sales_made):
        """SalesPerson works and generates commission from sales."""
        self.sales_made += sales_made
        commission = sales_made * self.commission_rate
        total_pay = self.weekly_salary + commission
        print(f"SalesPerson {self.name} worked for {hours} hours and made ${sales_made} in sales. "
              f"Commission earned: ${commission}. Total Pay: ${total_pay:.2f}")

# HourlyEmployee Class (inherits from Employee)
class HourlyEmployee(Employee):
    def __init__(self, emp_id, name, hourly_rate, hours_worked):
        super().__init__(emp_id, name)
        self.hourly_rate = hourly_rate
        self.hours_worked = hours_worked
    
    def calculate_payroll(self):
        """Returns the payroll for hourly employees, based on hours worked."""
        return self.hourly_rate * self.hours_worked
    
    def work(self, hours):
        """Factory workers are paid hourly based on how many hours they worked."""
        self.hours_worked += hours
        total_pay = self.calculate_payroll()
        print(f"Factory Worker {self.name} worked for {hours} hours. Total Pay: ${total_pay:.2f}")

# ProductivitySystem Class
class ProductivitySystem:
    def calculate_productivity(self, employees):
        """Calculate and print the productivity for each employee."""
        for employee in employees:
            print(f"Employee: {employee.name}")
            if isinstance(employee, SalesPerson):
                # SalesPerson needs to specify hours worked and sales made
                employee.work(40, 2000)  # Example: Worked 40 hours and made $2000 in sales
            else:
                employee.work(40)  # For others, just track hours worked (assuming 40 hours)
            print("=" * 40)

# Example Usage

# Create instances of different types of employees
manager1 = Manager(1, "Alice Johnson", 1500)
secretary1 = Secretary(2, "Bob Smith", 800)
salesperson1 = SalesPerson(3, "Charlie Brown", 1000, 0.1)  # 10% commission
factoryworker1 = HourlyEmployee(4, "David Lee", 20, 40)  # $20 per hour

# Create a list of employees
employees = [
    manager1, secretary1, salesperson1, factoryworker1
]

# Create a ProductivitySystem instance and calculate productivity for all employees
productivity_system = ProductivitySystem()
productivity_system.calculate_productivity(employees)
# Out:
# Employee: Alice Johnson
# Manager Alice Johnson worked for 40 hours, delegating tasks and overseeing operations.
# ...
# Employee: Bob Smith
# Secretary Bob Smith worked for 40 hours, handling paperwork and administration.
# ...
# Employee: Charlie Brown
# SalesPerson Charlie Brown worked for 40 hours and made $2000 in sales. Commission earned: $200.0. Total Pay: $1200.00
# ...
# Employee: David Lee
# Factory Worker David Lee worked for 40 hours. Total Pay: $1600.00
# ...

# %% [markdown]
# ## Problem 3:

# %% [markdown]
# <center>
#   <h3 style="color: #34495e; font-family: Arial, sans-serif; background-color: pink; padding: 8px; border-radius: 5px;">Electrical Department Employees</h3>
# </center>
#
# <h3 style="color: #34495e; font-family: Arial, sans-serif;">Objective</h3>
# <p style="color: #2c3e50; font-family: Arial, sans-serif; line-height: 1.6;">
#   Define a class hierarchy for employees in the electrical department, categorizing them into faculty and administrative staff. Each category will include different roles with specific responsibilities.
# </p>
#
# <h3 style="color: #34495e; font-family: Arial, sans-serif;">Class Structure</h3>
# <ol style="color: #2c3e50; font-family: Arial, sans-serif; line-height: 1.8;">
#   <li>
#     <strong style="color: #2980b9; background-color: #eafaf1; padding: 5px; border-radius: 5px;">Staff Class:</strong>
#     <ul>
#       <li>The <code>Staff</code> class serves as the base class for all employees in the electrical department.</li>
#       <li>It contains common attributes such as <code>name</code>, <code>employee_id</code>, and <code>department</code>.</li>
#       <li>The class includes a method to display basic staff details.</li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #e67e22; background-color: #fceae5; padding: 5px; border-radius: 5px;">Faculty Class:</strong>
#     <ul>
#       <li>The <code>Faculty</code> class inherits from <code>Staff</code> and represents teaching personnel.</li>
#       <li>It includes additional attributes such as <code>designation</code> and <code>courses_taught</code>.</li>
#       <li>The class contains a method to display faculty-specific details.</li>
#       <li>The faculty category includes:
#         <ul>
#           <li><strong>Lecturers</strong></li>
#           <li><strong>Assistant Professors</strong></li>
#           <li><strong>Associate Professors</strong></li>
#           <li><strong>Professors</strong></li>
#         </ul>
#       </li>
#     </ul>
#   </li>
#   <li>
#     <strong style="color: #27ae60; background-color: #eafaf1; padding: 5px; border-radius: 5px;">Admin Staff Class:</strong>
#     <ul>
#       <li>The <code>AdminStaff</code> class inherits from <code>Staff</code> and represents non-teaching personnel.</li>
#       <li>It includes attributes such as <code>role</code> and <code>responsibilities</code>.</li>
#       <li>The class contains a method to display administrative staff details.</li>
#       <li>The admin staff category includes:
#         <ul>
#           <li><strong>Lab Engineers</strong></li>
#           <li><strong>Lab Technicians</strong></li>
#           <li><strong>Lab Assistants</strong></li>
#           <li><strong>Lab Attendants</strong></li>
#         </ul>
#       </li>
#     </ul>
#   </li>
# </ol>

# %%
class EEDJ_Employee:
    def __init__(self, id, name, position, workload, scale, b_pay):
        self.id = id
        self.name = name 
        self.position = position 
        self.workload = workload 
        self.scale = scale
        self.b_pay = b_pay

    def __str__(self):
        return f"Employee ID: {self.id}, Name: {self.name}, Position: {self.position}, Workload: {self.workload}-Hours, Scale: {self.scale}, Base Pay: {self.b_pay}"

#-------------------------------------------------------------------------------------------------------------------------------------------------------------------

class Faculty(EEDJ_Employee):
    def __init__(self, id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode):
        super().__init__(id, name, position, workload, scale, b_pay)
        self.research = research
        self.subject = subject
        self.experiance = experiance
        self.teach_mode = teach_mode

    def __str__(self):
        return super().__str__() + f", Research: {self.research}, Subject: {self.subject}, Experience: {self.experiance} years, Teach Mode: {self.teach_mode}"

class Professor(Faculty):
    def __init__(self, id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode):
        super().__init__(id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode)
    
    def __str__(self):
        return super().__str__()

class Associate_Prof(Faculty):
    def __init__(self, id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode):
        super().__init__(id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode)
    
    def __str__(self):
        return super().__str__()

class Assistant_Prof(Faculty):
    def __init__(self, id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode):
        super().__init__(id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode)
    
    def __str__(self):
        return super().__str__()

class Lecturer(Faculty):
    def __init__(self, id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode):
        super().__init__(id, name, position, workload, scale, b_pay, research, subject, experiance, teach_mode)
    
    def __str__(self):
        return super().__str__()
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------

class Admin(EEDJ_Employee):
    def __init__(self, id, name, position, workload, scale, b_pay, lab_name="", lab_capacity=0):
        super().__init__(id, name, position, workload, scale, b_pay)
        self.lab_name = lab_name
        self.lab_capacity = lab_capacity

    def __str__(self):
        return super().__str__() + f", Lab Name: {self.lab_name}, Lab Capacity: {self.lab_capacity}"

class Lab_Engr(Admin):
    def __init__(self, id, name, position, workload, scale, b_pay, lab_name, lab_capacity,lab_subject):
        super().__init__(id, name, position, workload, scale, b_pay, lab_name, lab_capacity)
        self.lab_subject = lab_subject
    
    def __str__(self):
        return super().__str__() + f", Lab Subject: {self.lab_subject}"

class Lab_Technician(Admin):
    def __init__(self, id, name, position, workload, scale, b_pay, lab_name, lab_capacity,basic_lab):
        super().__init__(id, name, position, workload, scale, b_pay, lab_name, lab_capacity)
        self.basic_lab = basic_lab
        
    def __str__(self):
        return super().__str__() + f", Basic Lab : {self.basic_lab}"

class Lab_Assistant(Admin):
    def __init__(self, id, name, position, workload, scale, b_pay, lab_name, lab_capacity,equipment_handle):
        super().__init__(id, name, position, workload, scale, b_pay, lab_name, lab_capacity)
        self.equipment_handle = equipment_handle

    def __str__(self):
        return super().__str__() + f", Equipment Handle: {self.equipment_handle}"

class Lab_Attendant(Admin):
    def __init__(self, id, name, position, workload, scale, b_pay, lab_name, lab_capacity):
        super().__init__(id, name, position, workload, scale, b_pay, lab_name, lab_capacity)

    def __str__(self):
        return super().__str__()
    
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Objects For Faculty
A = Professor(1, "Dr Qaisar Ali", "Professor", 8, 21, 300000, "Electrical Machine", "Signal and System", "12 Years", "Multimedia")
B = Associate_Prof(2, "Akhtar Nawaz", "Associate Professor", 10, 20, 250000, "Power Analysis", "Circuit Analysis", "15 Years", "White Board")
C = Assistant_Prof(3, "Waqas Imtiaz", "Assistant Professor", 12, 19, 200000, "Electric Cars", "Circuit Analysis", "5 Years", "Projector")
D = Lecturer(4, "Irshad Ullah Sir", "Lecturer", 14, 18, 100000, "Renewable Energy", "OPPs And Ds", "7 Years", "Projector")

# %%
# Objects For Admin
E = Lab_Engr(5, "Waqar Hussain", "Lab Engineer", 18, 17, 150000, "Instrumentation", 60, "Circuit-1")
F = Lab_Technician(6, "Wajid Ali", "Lab Technician", 16, 16, 100000, "Electronics Lab", 50, "DLD")
G = Lab_Assistant(7, "M.Haris", "Lab Assistant", 15, 16, 70000, "Power Engineering Lab", 54, "AutoCAD")
H = Lab_Attendant(8, "Shahzaib Khan", "Lab Attendant", 14, 15, 50000, "Computer Lab", 33)

# %%
# List of objects
employees = [
    Professor(1, "Dr Qaisar Ali", "Professor", 8, 21, 300000, "Electrical Machine", "Signal and System", "12 Years", "Multimedia"),
    Associate_Prof(2, "Akhtar Nawaz", "Associate Professor", 10, 20, 250000, "Power Analysis", "Circuit Analysis", "15 Years", "White Board"),
    Assistant_Prof(3, "Waqas Imtiaz", "Assistant Professor", 12, 19, 200000, "Electric Cars", "Circuit Analysis", "5 Years", "Projector"),
    Lecturer(4, "Irshad Ullah Sir", "Lecturer", 14, 18, 100000, "Renewable Energy", "OPPs And Ds", "7 Years", "Projector"),
    Lab_Engr(5, "Waqar Hussain", "Lab Engineer", 18, 17, 150000, "Instrumentation", 60, "Circuit-1"),
    Lab_Technician(6, "Wajid Ali", "Lab Technician", 16, 16, 100000, "Electronics Lab", 50, "DLD"),
    Lab_Assistant(7, "M.Haris", "Lab Assistant", 15, 16, 70000, "Power Engineering Lab", 54, "AutoCAD"),
    Lab_Attendant(8, "Shahzaib Khan", "Lab Attendant", 14, 15, 50000, "Computer Lab", 33),
]

# %%
# Print all objects
for employee in employees:
    print(employee)
# Out:
# Employee ID: 1, Name: Dr Qaisar Ali, Position: Professor, Workload: 8-Hours, Scale: 21, Base Pay: 300000, Research: Electrical Machine, Subject: Signal and System, Experience: 12 Years years, Teach Mode: Multimedia
# Employee ID: 2, Name: Akhtar Nawaz, Position: Associate Professor, Workload: 10-Hours, Scale: 20, Base Pay: 250000, Research: Power Analysis, Subject: Circuit Analysis, Experience: 15 Years years, Teach Mode: White Board
# Employee ID: 3, Name: Waqas Imtiaz, Position: Assistant Professor, Workload: 12-Hours, Scale: 19, Base Pay: 200000, Research: Electric Cars, Subject: Circuit Analysis, Experience: 5 Years years, Teach Mode: Projector
# Employee ID: 4, Name: Irshad Ullah Sir, Position: Lecturer, Workload: 14-Hours, Scale: 18, Base Pay: 100000, Research: Renewable Energy, Subject: OPPs And Ds, Experience: 7 Years years, Teach Mode: Projector
# ...

# %% [markdown]
# ---------------------------------------
