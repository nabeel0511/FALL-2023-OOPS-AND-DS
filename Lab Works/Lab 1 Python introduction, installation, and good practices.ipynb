# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 20px 15px;
#         border-radius: 20px;
#         background: linear-gradient(135deg, #f9f9f9, #ffffff);
#         max-width: 900px; /* Increased width */
#         box-shadow: 0 8px 20px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 30px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 2px;
#             margin-bottom: 15px;
#         "
#     >
#         University of Engineering and Technology Peshawar
#     </h1>
#     <h2
#         style="
#             font-family: 'Georgia', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 5px;
#             font-style: italic;
#         "
#     >
#         Jalozai Campus
#     </h2>
# </div>

# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border-radius: 20px;
#         background: linear-gradient(135deg, #f3f4f6, #ffffff);
#         max-width: 800px;
#         box-shadow: 0 10px 25px rgba(0, 0, 0, 0.15);
#         text-align: center;
#         border: 1px solid #e0e0e0;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 32px;
#             color: #2c3e50;
#             text-transform: capitalize;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#             margin-bottom: 20px;
#         "
#     >
#         Lab Title: EE-271 “OOP & Data Structures Lab”
#     </h1>
# </div>

# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border-radius: 20px;
#         background: linear-gradient(135deg, #f3f4f6, #ffffff);
#         max-width: 800px;
#         box-shadow: 0 10px 25px rgba(0, 0, 0, 0.15);
#         text-align: center;
#         border: 1px solid #e0e0e0;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 25px;
#             color: #2c3e50;
#             text-transform: capitalize;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#             margin-bottom: 20px;
#         "
#     >
#         Lab 1: Python introduction, installation, and good practices
#     </h1>
# </div>

# %% [markdown]
# ## Prepared By: Nabeel Ahmad

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# ### 🖥 <span style="color: #2c3e50;">1. Install IDE</span>
#
# #### Recommended IDEs for Python:
#
# - <a href="https://www.anaconda.com/download" style="color: #3498db;">Anaconda</a>: Recommended for managing environments.
# - <a href="https://www.python.org/downloads/" style="color: #3498db;">Python Official Download</a>: Standard Python download for development.
#
# ---
#
# ### 👨‍💻 <span style="color: #2c3e50;">2. Make a GitHub Account</span>
#
# - To create a GitHub account, follow this <a href="https://github.com/" style="color: #3498db;">link</a>.
#
# ---
#
# ### 🌐 <span style="color: #2c3e50;">3. Helpful Websites</span>
#
# - <a href="https://stackoverflow.com/" style="color: #3498db;">Stack Overflow</a>: A community-driven Q&A platform for programming-related queries.
# - <a href="https://realpython.com/" style="color: #3498db;">Real Python</a>: High-quality tutorials for Python developers. You can also follow their <a href="https://www.youtube.com/@realpython" style="color: #3498db;">YouTube Channel</a>.
# - <a href="https://www.geeksforgeeks.org/" style="color: #3498db;">Geeks for Geeks</a>: Learn concepts through detailed tutorials and explanations.
# - <a href="https://www.w3schools.com/CPP/default.asp" style="color: #3498db;">W3Schools</a>: Beginner-friendly tutorials for a wide range of programming topics.
#
# ---
#
# ### 📓 <span style="color: #2c3e50;">4. Jupyter Notebook</span>
#
# - Learn how to use Jupyter Notebook effectively with this <a href="https://www.youtube.com/watch?v=HW29067qVWk&t=27s" style="color: #3498db;">walkthrough video</a>.
#
# ---
#
# ### ⚙️ <span style="color: #2c3e50;">5. Virtual Environments</span>
#
# - Creating virtual environments ensures that each project has its own dependencies. You can learn how to create a virtual environment <a href="https://www.youtube.com/watch?v=23aQdrS58e0&t=10s" style="color: #3498db;">here</a>.
#
# ---
#
# ### 🌍 <span style="color: #2c3e50;">6. Online Code Editors</span>
#
# - Run your Python code online using <a href="https://colab.google/" style="color: #3498db;">Google Colab</a>.
#
# ---
#
# ### 🎓 <span style="color: #2c3e50;">7. Recommended Courses</span>
#
# - <a href="https://www.coursera.org/specializations/python" style="color: #3498db;">Python for Everybody Specialization on Coursera</a>: This specialization includes excellent introductory courses.
# - Watch these free courses on <a href="https://www.youtube.com/watch?v=UjeNA_JtXME&list=PLlRFEj9H3Oj7Bp8-DfGpfAfDBiblRfl5p" style="color: #3498db;">YouTube</a>.
#
# ---
#
# ### 📚 <span style="color: #2c3e50;">8. Recommended GitHub Resource</span>
#
# - Explore Python codes and examples in this <a href="https://github.com/SyedHasnat/OOP-in-Python-UET/tree/main" style="color: #3498db;">GitHub Repository</a>.
#
# ---
#
# ### 📖 <span style="color: #2c3e50;">9. Recommended Books</span>
#
# - **Python Tricks: The Book** by Dan Bader
# - **How to Think Like a Computer Scientist** by Allen Downey
#
# ---
#
# <footer style="text-align: center; color: #34495e;">
#     <p>&copy; 2024 University of Engineering and Technology Peshawar, Jalozai Campus. All Rights Reserved.</p>
# </footer>
